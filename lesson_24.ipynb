# %%
import pandas as pd

# %%
df = pd.read_csv(rf"D:\Programming\excalibur\data\train.csv")
final_test_df = pd.read_csv(fr"data\test.csv")

# %%
df
# Out:
#             id        date    country         store  \
# 0            0  2017-01-01  Argentina  Kaggle Learn
# 1            1  2017-01-01  Argentina  Kaggle Learn
# 2            2  2017-01-01  Argentina  Kaggle Learn
# 3            3  2017-01-01  Argentina  Kaggle Learn
# 4            4  2017-01-01  Argentina  Kaggle Learn
# ...        ...         ...        ...           ...
# 136945  136945  2021-12-31      Spain     Kagglazon
# 136946  136946  2021-12-31      Spain     Kagglazon
# 136947  136947  2021-12-31      Spain     Kagglazon
# 136948  136948  2021-12-31      Spain     Kagglazon
# 136949  136949  2021-12-31      Spain     Kagglazon
#
#                                                product  num_sold
# 0                    Using LLMs to Improve Your Coding        63
# 1                        Using LLMs to Train More LLMs        66
# 2       Using LLMs to Win Friends and Influence People         9
# 3           Using LLMs to Win More Kaggle Competitions        59
# ...

# %%
final_test_df.describe(include='all')
# Out:
#                    id        date    country         store  \
# count    27375.000000       27375      27375         27375
# unique            NaN         365          5             3
# top               NaN  2022-12-31  Argentina  Kaggle Learn
# freq              NaN          75       5475          9125
# mean    150637.000000         NaN        NaN           NaN
# std       7902.626146         NaN        NaN           NaN
# min     136950.000000         NaN        NaN           NaN
# 25%     143793.500000         NaN        NaN           NaN
# 50%     150637.000000         NaN        NaN           NaN
# 75%     157480.500000         NaN        NaN           NaN
# max     164324.000000         NaN        NaN           NaN
#
#                                   product
# count                               27375
# unique                                  5
# top     Using LLMs to Improve Your Coding
# freq                                 5475
# ...

# %%
final_test_df.sort_values("date")
# Out:
#            id        date    country         store  \
# 0      136950  2022-01-01  Argentina  Kaggle Learn
# 54     137004  2022-01-01      Japan  Kaggle Store
# 53     137003  2022-01-01      Japan  Kaggle Store
# 52     137002  2022-01-01      Japan  Kaggle Store
# 51     137001  2022-01-01      Japan  Kaggle Store
# ...       ...         ...        ...           ...
# 27321  164271  2022-12-31     Canada  Kaggle Store
# 27320  164270  2022-12-31     Canada  Kaggle Store
# 27319  164269  2022-12-31     Canada  Kaggle Learn
# 27326  164276  2022-12-31     Canada     Kagglazon
# 27374  164324  2022-12-31      Spain     Kagglazon
#
#                                               product
# 0                   Using LLMs to Improve Your Coding
# 54                         Using LLMs to Write Better
# 53         Using LLMs to Win More Kaggle Competitions
# 52     Using LLMs to Win Friends and Influence People
# 51                      Using LLMs to Train More LLMs
# ...

# %%
final_test_df.groupby(['country', "store", 'product']).size().value_counts()
# Out:
# 365    75
# Name: count, dtype: int64

# %%
df
# Out:
#             id        date    country         store  \
# 0            0  2017-01-01  Argentina  Kaggle Learn
# 1            1  2017-01-01  Argentina  Kaggle Learn
# 2            2  2017-01-01  Argentina  Kaggle Learn
# 3            3  2017-01-01  Argentina  Kaggle Learn
# 4            4  2017-01-01  Argentina  Kaggle Learn
# ...        ...         ...        ...           ...
# 136945  136945  2021-12-31      Spain     Kagglazon
# 136946  136946  2021-12-31      Spain     Kagglazon
# 136947  136947  2021-12-31      Spain     Kagglazon
# 136948  136948  2021-12-31      Spain     Kagglazon
# 136949  136949  2021-12-31      Spain     Kagglazon
#
#                                                product  num_sold
# 0                    Using LLMs to Improve Your Coding        63
# 1                        Using LLMs to Train More LLMs        66
# 2       Using LLMs to Win Friends and Influence People         9
# 3           Using LLMs to Win More Kaggle Competitions        59
# ...

# %%
df.sort_values(['date', 'country', 'store', 'product'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 136950 entries, 10 to 136944
# Data columns (total 6 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        136950 non-null  int64
#  1   date      136950 non-null  object
#  2   country   136950 non-null  object
#  3   store     136950 non-null  object
#  4   product   136950 non-null  object
#  5   num_sold  136950 non-null  int64
# dtypes: int64(2), object(4)
# memory usage: 7.3+ MB

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 136950 entries, 10 to 136944
# Data columns (total 6 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   id        136950 non-null  int64
#  1   date      136950 non-null  datetime64[ns]
#  2   country   136950 non-null  object
#  3   store     136950 non-null  object
#  4   product   136950 non-null  object
#  5   num_sold  136950 non-null  int64
# dtypes: datetime64[ns](1), int64(2), object(3)
# memory usage: 7.3+ MB

# %%
df
# Out:
#             id       date    country         store  \
# 10          10 2017-01-01  Argentina     Kagglazon
# 11          11 2017-01-01  Argentina     Kagglazon
# 12          12 2017-01-01  Argentina     Kagglazon
# 13          13 2017-01-01  Argentina     Kagglazon
# 14          14 2017-01-01  Argentina     Kagglazon
# ...        ...        ...        ...           ...
# 136940  136940 2021-12-31      Spain  Kaggle Store
# 136941  136941 2021-12-31      Spain  Kaggle Store
# 136942  136942 2021-12-31      Spain  Kaggle Store
# 136943  136943 2021-12-31      Spain  Kaggle Store
# 136944  136944 2021-12-31      Spain  Kaggle Store
#
#                                                product  num_sold
# 10                   Using LLMs to Improve Your Coding       340
# 11                       Using LLMs to Train More LLMs       371
# 12      Using LLMs to Win Friends and Influence People        53
# 13          Using LLMs to Win More Kaggle Competitions       364
# ...

# %%
df['date']
# Out:
# 10       2017-01-01
# 11       2017-01-01
# 12       2017-01-01
# 13       2017-01-01
# 14       2017-01-01
#             ...
# 136940   2021-12-31
# 136941   2021-12-31
# 136942   2021-12-31
# 136943   2021-12-31
# 136944   2021-12-31
# Name: date, Length: 136950, dtype: datetime64[ns]

# %%
df.groupby(df["date"].dt.year).num_sold.sum().plot()
# Out:
# <Axes: xlabel='date'>

# %%
df.groupby('country').num_sold.sum().plot()
# Out:
# <Axes: xlabel='country'>

# %%
df.groupby(['country', 'store', 'product']).size().value_counts()
# Out:
# 1826    75
# Name: count, dtype: int64

# %%
df['product'].value_counts()
# Out:
# product
# Using LLMs to Improve Your Coding                 27390
# Using LLMs to Train More LLMs                     27390
# Using LLMs to Win Friends and Influence People    27390
# Using LLMs to Win More Kaggle Competitions        27390
# Using LLMs to Write Better                        27390
# Name: count, dtype: int64

# %%
df['store'].value_counts()
# Out:
# store
# Kagglazon       45650
# Kaggle Learn    45650
# Kaggle Store    45650
# Name: count, dtype: int64

# %%
df.groupby(df["date"].dt.dayofweek).num_sold.sum().plot()
# Out:
# <Axes: xlabel='date'>

# %%
df.groupby(df["date"].dt.month).num_sold.sum().plot()
# Out:
# <Axes: xlabel='date'>

# %%
df.groupby("date").num_sold.sum().plot(figsize=(20,6))
# Out:
# <Axes: xlabel='date'>

# %%
import matplotlib.pyplot as plt

# %%
df
# Out:
#             id       date    country         store  \
# 10          10 2017-01-01  Argentina     Kagglazon
# 11          11 2017-01-01  Argentina     Kagglazon
# 12          12 2017-01-01  Argentina     Kagglazon
# 13          13 2017-01-01  Argentina     Kagglazon
# 14          14 2017-01-01  Argentina     Kagglazon
# ...        ...        ...        ...           ...
# 136940  136940 2021-12-31      Spain  Kaggle Store
# 136941  136941 2021-12-31      Spain  Kaggle Store
# 136942  136942 2021-12-31      Spain  Kaggle Store
# 136943  136943 2021-12-31      Spain  Kaggle Store
# 136944  136944 2021-12-31      Spain  Kaggle Store
#
#                                                product  num_sold
# 10                   Using LLMs to Improve Your Coding       340
# 11                       Using LLMs to Train More LLMs       371
# 12      Using LLMs to Win Friends and Influence People        53
# 13          Using LLMs to Win More Kaggle Competitions       364
# ...

# %%
df[(df['country'] == "Argentina") & (df['store']== "Kagglazon") & (df['product'] == "Using LLMs to Improve Your Coding")].set_index('date').num_sold.plot(figsize=(30, 6))
# Out:
# <Axes: xlabel='date'>

# %%
from sklearn.model_selection import TimeSeriesSplit

tscv = TimeSeriesSplit(n_splits=5)

# %%
info = df['date'].dt.isocalendar().week

# %%
info
# Out:
# 10        52
# 11        52
# 12        52
# 13        52
# 14        52
#           ..
# 136940    52
# 136941    52
# 136942    52
# 136943    52
# 136944    52
# Name: week, Length: 136950, dtype: UInt32

# %%
df.date.dt.dayofyear
# Out:
# 10          1
# 11          1
# 12          1
# 13          1
# 14          1
#          ...
# 136940    365
# 136941    365
# 136942    365
# 136943    365
# 136944    365
# Name: date, Length: 136950, dtype: int32

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
d = pd.DataFrame()
d['dayofyear'] = df.date.dt.dayofyear
d['doy_sin'] = np.sin(2*np.pi * df.date.dt.dayofyear/366)
d['doy_cos'] = np.cos(2*np.pi * df.date.dt.dayofyear/366)

# %%
d
# Out:
#         dayofyear   doy_sin   doy_cos
# 10              1  0.017166  0.999853
# 11              1  0.017166  0.999853
# 12              1  0.017166  0.999853
# 13              1  0.017166  0.999853
# 14              1  0.017166  0.999853
# ...           ...       ...       ...
# 136940        365 -0.017166  0.999853
# 136941        365 -0.017166  0.999853
# 136942        365 -0.017166  0.999853
# 136943        365 -0.017166  0.999853
# 136944        365 -0.017166  0.999853
#
# [136950 rows x 3 columns]
